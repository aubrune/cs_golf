# %%
from numpy.random import random
import numpy

# %%
num_possible_durations = 10
num_possible_angles = 30
initial_noise_range = 20

# %%
data = initial_noise_range*random((num_possible_durations, num_possible_angles)) + 50

# %%
numpy.max(data)
# Out:
# 69.83026479927572

# %%
i_max_dur, i_max_angle = numpy.unravel_index(numpy.argmax(data, axis=None), data.shape)
max_score = data[i_max_dur, i_max_angle]

# %%
# Play trajectory #i_max_dur, i_max_angle

# %%
# Get score of this trajectory from the user
score = 6

# %%
data[2][15]
# Out:
# 69.83026479927572

# %%
mu = 50
sigma = 10
def gauss(x):
    return numpy.exp(-(x-mu)*(x-mu)/(2*sigma*sigma))

# %%
x = numpy.linspace(0, 100, 50)

# %%
gauss(x)
# Out:
# array([3.72665317e-06, 1.01258754e-05, 2.63911377e-05, 6.59774581e-05,
#        1.58214026e-04, 3.63920328e-04, 8.02933509e-04, 1.69927937e-03,
#        3.44954582e-03, 6.71693252e-03, 1.25456159e-02, 2.24763052e-02,
#        3.86251152e-02, 6.36687888e-02, 1.00668900e-01, 1.52677834e-01,
#        2.22110244e-01, 3.09936785e-01, 4.14848563e-01, 5.32620638e-01,
#        6.55931254e-01, 7.74837429e-01, 8.77960125e-01, 9.54225295e-01,
#        9.94807364e-01, 9.94807364e-01, 9.54225295e-01, 8.77960125e-01,
#        7.74837429e-01, 6.55931254e-01, 5.32620638e-01, 4.14848563e-01,
#        3.09936785e-01, 2.22110244e-01, 1.52677834e-01, 1.00668900e-01,
#        6.36687888e-02, 3.86251152e-02, 2.24763052e-02, 1.25456159e-02,
#        6.71693252e-03, 3.44954582e-03, 1.69927937e-03, 8.02933509e-04,
#        3.63920328e-04, 1.58214026e-04, 6.59774581e-05, 2.63911377e-05,
#        1.01258754e-05, 3.72665317e-06])

# %%
from matplotlib.pyplot import 
plot(x, gauss(x), gauss(x))

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, gauss(x), (numpy.ones(numpy.size(x)), gauss(x)), color='b')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-9670ddeb1018> in <module>()
#       1 fig = plt.figure()
#       2 ax = fig.add_subplot(111, projection='3d')
# ----> 3 ax.plot_surface(x, gauss(x), (numpy.ones(numpy.size(x)), gauss(x)), color='b')
#
# /usr/lib/python2.7/dist-packages/mpl_toolkits/mplot3d/axes3d.pyc in plot_surface(self, X, Y, Z, *args, **kwargs)
#    1619         had_data = self.has_data()
#    1620
# -> 1621         if Z.ndim != 2:
#    1622             raise ValueError("Argument Z must be 2-dimensional.")
#    1623         # TODO: Support masked arrays
#
# AttributeError: 'tuple' object has no attribute 'ndim'

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np


fig = plt.figure()
ax = fig.gca(projection='3d')

# Make data.
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
# TODO : Cellule précédente OK mais je veux plot la gaussienne moi
